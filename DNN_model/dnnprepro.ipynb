# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('final_result.xlsx')

# %%
print(df)
# Out:
#              발매일                              제품명     모델번호       발매가   브랜드  \
# 0     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원  뉴발란스
# 1     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원  뉴발란스
# 2     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원  뉴발란스
# 3     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원  뉴발란스
# 4     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원  뉴발란스
# ...          ...                              ...      ...       ...   ...
# 43948 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   컨버스
# 43949 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   컨버스
# 43950 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   컨버스
# 43951 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   컨버스
# 43952 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   컨버스
#
# ...

# %%
df['브랜드']  = np.where(df['브랜드'] == '나이키', 1, df['브랜드'])

# %%
df['브랜드']  = np.where(df['브랜드'] == '뉴발란스', 3, df['브랜드'])

# %%
df['브랜드']  = np.where(df['브랜드'] == '조던', 2, df['브랜드'])

# %%
df['브랜드']  = np.where(df['브랜드'] == '아디다스', 4, df['브랜드'])

# %%
df['브랜드']  = np.where(df['브랜드'] == '컨버스', 5, df['브랜드'])

# %%
print(df)
# Out:
#              발매일                              제품명     모델번호       발매가 브랜드  \
# 0     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3
# 1     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3
# 2     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3
# 3     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3
# 4     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3
# ...          ...                              ...      ...       ...  ..
# 43948 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5
# 43949 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5
# 43950 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5
# 43951 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5
# 43952 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5
#
#              라인 콜라보 브랜드    색상       sns 검색 키워드         날짜  리셀가능여부       검색량  \
# ...

# %%
df['라인']  = np.where(df['라인'] == '에어포스', 1, df['라인'])
df['라인']  = np.where(df['라인'] == '에어맥스95', 2, df['라인'])
df['라인']  = np.where(df['라인'] == '에어맥스97', 3, df['라인'])
df['라인']  = np.where(df['라인'] == '에어 베이퍼맥스', 4, df['라인'])
df['라인']  = np.where(df['라인'] == '데이브레이크', 5, df['라인'])
df['라인']  = np.where(df['라인'] == '에어 모어', 6, df['라인'])
df['라인']  = np.where(df['라인'] == '코비', 7, df['라인'])
df['라인']  = np.where(df['라인'] == '블레이저', 8, df['라인'])

# %%
df['라인']  = np.where(df['라인'] == '조던1', 9, df['라인'])
df['라인']  = np.where(df['라인'] == '조던3', 10, df['라인'])
df['라인']  = np.where(df['라인'] == '조던4', 11, df['라인'])
df['라인']  = np.where(df['라인'] == '조던5', 12, df['라인'])
df['라인']  = np.where(df['라인'] == '조던6', 13, df['라인'])
df['라인']  = np.where(df['라인'] == '조던11', 14, df['라인'])
df['라인']  = np.where(df['라인'] == '조던13', 15, df['라인'])

# %%
df['라인']  = np.where(df['라인'] == '뉴발란스 237', 16, df['라인'])
df['라인']  = np.where(df['라인'] == '뉴발란스 327', 17, df['라인'])
df['라인']  = np.where(df['라인'] == '뉴발란스 530', 18, df['라인'])
df['라인']  = np.where(df['라인'] == '뉴발란스 990', 19, df['라인'])
df['라인']  = np.where(df['라인'] == '뉴발란스 991', 20, df['라인'])
df['라인']  = np.where(df['라인'] == '뉴발란스 992', 21, df['라인'])
df['라인']  = np.where(df['라인'] == '뉴발란스 993', 22, df['라인'])
df['라인']  = np.where(df['라인'] == '뉴발란스 1300', 23, df['라인'])
df['라인']  = np.where(df['라인'] == '뉴발란스 2002', 24, df['라인'])

# %%
df['라인']  = np.where(df['라인'] == '아디다스 이지', 25, df['라인'])
df['라인']  = np.where(df['라인'] == '아디다스 슈퍼스타', 26, df['라인'])
df['라인']  = np.where(df['라인'] == '컨버스 런스타', 27, df['라인'])
df['라인']  = np.where(df['라인'] == '컨버스 척 70', 28, df['라인'])

# %%
print(df)
# Out:
#              발매일                              제품명     모델번호       발매가 브랜드  라인  \
# 0     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 1     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 2     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 3     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 4     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# ...          ...                              ...      ...       ...  ..  ..
# 43948 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43949 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43950 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43951 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43952 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
#
# ...

# %%
df['month'] = df['발매일'].dt.strftime('%m')

# %%
print(df)
# Out:
#              발매일                              제품명     모델번호       발매가 브랜드  라인  \
# 0     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 1     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 2     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 3     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 4     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# ...          ...                              ...      ...       ...  ..  ..
# 43948 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43949 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43950 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43951 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43952 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
#
# ...

# %%
df['콜라보 브랜드'] = df['콜라보 브랜드'].fillna(0)

# %%
print(df)
# Out:
#              발매일                              제품명     모델번호       발매가 브랜드  라인  \
# 0     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 1     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 2     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 3     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 4     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# ...          ...                              ...      ...       ...  ..  ..
# 43948 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43949 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43950 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43951 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43952 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
#
# ...

# %%
df1 = df.drop_duplicates(['콜라보 브랜드'], keep = 'first')

# %%
print(df1)
# Out:
#              발매일                                          제품명  \
# 0     2020-04-13              뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드
# 1288  2021-01-22                       뉴발란스 x 파타 991 메이드 인 UK
# 6067  2020-07-03                   뉴발란스 x 사이즈? 327 옐로우 그린 오렌지
# 6345  2021-03-09         뉴발란스 x 카사블랑카 327 아이디얼리스트 모노그램 화이트 그린
# 6531  2020-11-10                 뉴발란스 x 리바이스 327 네이비 (리바이스 택)
# 6624  2020-08-29           뉴발란스 x 도쿄 디자인 스튜디오 R_C 1300 말라드 블루
# 6903  2022-01-26                        뉴발란스 x 제이크루 2002R 인센스
# 7364  2020-05-01                뉴발란스 x 더블탭스 992 메이드 인 USA 올리브
# 7457  2020-09-12              뉴발란스 x JJJ자운드 992 메이드 인 USA 그레이
# 7641  2020-09-12                      뉴발란스 x 패커 992 메이드 인 USA
# 8008  2020-12-25          뉴발란스 x 키스 992 메이드 인 USA 키쓰마스 라이트 리프
# 8471  2020-09-21                     뉴발란스 x 디스이즈네버댓 2002R 화이트
# 8563  2020-10-23               뉴발란스 x 살레헤 벰버리 2002R 피스 비 더 저니
# 8749  2021-06-05              뉴발란스 x 베이프 2002R 블랙 카모 (스페셜 박스)
# ...

# %%
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '파타', 1, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '사이즈?', 2, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '카사블랑카', 3, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '리바이스', 4, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '도쿄디자인스튜디오', 5, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '제이크루', 6, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '더블탭스', 7, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == 'JJJ자운드', 8, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '패커', 9, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '키스', 10, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '디스이즈네버댓', 11, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '살레헤 벰버리', 12, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '베이프', 13, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '오프화이트', 14, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '트래비스 스캇', 15, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '크래비스스캇', 15, df['콜라보 브랜드'])

# %%
print(df)
# Out:
#              발매일                              제품명     모델번호       발매가 브랜드  라인  \
# 0     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 1     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 2     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 3     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# 4     2020-04-13  뉴발란스 992 메이드 인 USA 그레이 - D 스탠다드   M992GR  259,000원   3  21
# ...          ...                              ...      ...       ...  ..  ..
# 43948 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43949 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43950 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43951 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
# 43952 2021-10-12           컨버스 x 펑첸왕 척 70 투인원 그레이  171838C  209,000원   5  28
#
# ...

# %%
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '프라그먼트', 16, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '앰부쉬', 17, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '스투시', 18, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '클랏', 19, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '스페이스잼', 20, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == 'NBA', 21, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '밴앤제리스', 22, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '스트레이지러브', 23, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '슈프림', 24, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '카시나', 25, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '그레이트풀데드', 26, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '션클리버', 27, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '트래비스스캇/프라그먼트', 28, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '아 마 마니에르', 29, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '파리생제르맹', 30, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '사카이', 31, df['콜라보 브랜드'])

# %%
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '레디메이드', 32, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '사카이 카우스', 33, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == 'FPAR', 34, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '몽클레르 / 플라그먼트', 35, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '킴 존스', 36, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '다크 쉐도우', 37, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '다크쉐도우', 37, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '피어 오브 갓', 38, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '프라다', 39, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '펑첸왕', 40, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '키스 해링', 41, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '골프왕', 42, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '브레인 데드', 43, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '칼하트 WIP', 44, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '반둘루', 45, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '스펜서 멕멀렌', 46, df['콜라보 브랜드'])
df['콜라보 브랜드']  = np.where(df['콜라보 브랜드'] == '레고', 47, df['콜라보 브랜드'])

# %%
df.to_csv('semi.csv', encoding = "utf-8-sig")
